# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens = element.split(".")
        df_tokens.extend(tokens)
df_text = " ".join(df_tokens)

# Read the dictionary content from the file
dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

# Function to find suggestions for a misspelled word
def suggest_corrections(word, dictionary):
    # This is a basic example; you can customize this based on your requirements
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

# Function to identify misspelled words and suggest corrections
def identify_misspelled_words(text, dictionary):
    misspelled_words = []
    suggestions = {}

    words = [word.strip(".,?!;:'\"()[]{}") for word in text.split()]

    for word in words:
        if word.lower() not in dictionary:
            misspelled_words.append(word)
            suggestions[word] = suggest_corrections(word, dictionary)

    return misspelled_words, suggestions

# Identify misspelled words and suggest corrections
misspelled_words, suggestions = identify_misspelled_words(df_text, dictionary_content)

# Print or use the results
if misspelled_words:
    print("Misspelled words:")
    print(misspelled_words)

    print("\nSuggestions:")
    for word, suggestion_list in suggestions.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens = element.split(".")
        df_tokens.extend(tokens)
df_text = " ".join(df_tokens)

# Read the dictionary content from the file
dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

# Function to find suggestions for a misspelled word
def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

# Function to identify misspelled words and suggest corrections
def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            misspelled_words[word] = suggestions
    return misspelled_words

# Identify misspelled words and suggest corrections
misspelled_words = identify_misspelled_words(df_text, dictionary_content)

# Print or use the results
if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens = element.split(".")
        df_tokens.extend(tokens)
df_text = " ".join(df_tokens)

# Read the dictionary content from the file
dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

# Function to find suggestions for a misspelled word
def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

# Function to identify misspelled words and suggest corrections
def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:  # Check if there are suggestions
                misspelled_words[word] = suggestions
    return misspelled_words

# Identify misspelled words and suggest corrections
misspelled_words = identify_misspelled_words(df_text, dictionary_content)

# Print or use the results
if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens = element.split(".")
        df_tokens.extend(tokens)
df_text = " ".join(df_tokens)
sd=pd.read_csv(r"C:\Users\ACER\Downloads\industry.1.txt")
sd_tokens= []
for index, row in sd.iterrows():
    for element in row:
        tokens = element.split(".") 
        sd_tokens.extend(tokens)
sd_text = " ".join(df_tokens)


# Read the dictionary content from the file
#dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
#with open(dictionary_file_path, 'r') as file:
 #   dictionary_content = file.read().lower().split()
# Function to find suggestions for a misspelled word
def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

# Function to identify misspelled words and suggest corrections
def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:  # Check if there are suggestions
                misspelled_words[word] = suggestions
    return misspelled_words

# Identify misspelled words and suggest corrections
misspelled_words = identify_misspelled_words(df_text, sd_text)

# Print or use the results
if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens= element.lower().strip().split(',')
        #tokens = element.split(".")
        df_tokens.extend(tokens)
        
df_text = " ".join(df_tokens)

# Read the dictionary content from the file
dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

# Function to find suggestions for a misspelled word
def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

# Function to identify misspelled words and suggest corrections
def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:  # Check if there are suggestions
                misspelled_words[word] = suggestions
    return misspelled_words

# Identify misspelled words and suggest corrections
misspelled_words = identify_misspelled_words(df_text, dictionary_content)

# Print or use the results
if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")

# %%
import pandas as df
df = df.read_csv(r"C:\Users\ACER\Downloads\industry.csv")
df_tokens = []
for index, row in df.iterrows():
    for element in row:
        tokens = element.split(".")
        df_tokens.extend(tokens)
print(df_tokens )

# %%
filepath=r"C:\Users\ACER\Downloads\industry.csv"
with open(filepath,"r") as file:
    for line in file:
      print(line.strip())

# %%
df=r"C:\Users\ACER\Downloads\industry.csv"
with open(df,"r") as file:
 df_tokens = []
for line in df:
 elements = line.strip().split(',')
for element in elements:
    tokens = element.lower().strip().split(',')
    df_tokens.extend(tokens)
df_text = " ".join(df_tokens)

dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()


def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]/{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions: 
                misspelled_words[word] = suggestions
    return misspelled_words


misspelled_words = identify_misspelled_words(df_text, dictionary_content)


if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")
# Out:
# Misspelled words and suggestions:
# v: ['advertising/public', 'aerospace/aviation', 'automotive', 'development', 'clerical/administrative', 'service', 'government/military', 'hospitality/travel', 'management/executive', 'non-profit/volunteer', 'services', 'service']

# %%
def editdistance(df,dictionary_file_path):
 lens=length(r"C:\Users\ACER\Downloads\industry.csv")
 lens2=(r"C:\Users\ACER\Downloads\industry.1.txt")
 dp = initialize_matrix(lens+ 1, lens2 + 1)
  for i from 0 to lens:
        dp[i][0] = i
  for j from 0 to lens2:
        dp[0][j] = j
    for i from 1 to lens:
        for j from 1 to lens2:
            if s1[i-1] = s2[j-1]:
                dp[i][j] = dp[i-1][j-1]
            else:
                dp[i][j] = min(dp[i-1][j], dp[i][j-1], dp[i-1][j-1]) + 1

    return dp[lens][lens2]
df=r"C:\Users\ACER\Downloads\industry.csv"
with open(df,"r") as file:
 df_tokens = []
for line in df:
 elements = line.strip().split(',')
for element in elements:
    tokens = element.lower().strip().split(',')
    df_tokens.extend(tokens)
df_text = " ".join(df_tokens)

dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()


def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if len(set(word) & set(w)) > len(set(word)) // 2]
    return suggestions

def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]/{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions: 
                misspelled_words[word] = suggestions
    return misspelled_words


misspelled_words = identify_misspelled_words(df_text, dictionary_content)


if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")
# Out:
#   File <string>:9
#     for i from 1 to lens:
#                          ^
# IndentationError: unindent does not match any outer indentation level

# %%
def initialize_matrix(rows, cols):
    return [[0] * cols for _ in range(rows)]
def levenshtein_distance(s1, s2):
    len_s1, len_s2 = len(s1), len(s2)
    dp = initialize_matrix(len_s1 + 1, len_s2 + 1)

    for i in range(len_s1 + 1):
        dp[i][0] = i
    for j in range(len_s2 + 1):
        dp[0][j] = j

    for i in range(1, len_s1 + 1):
        for j in range(1, len_s2 + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1]) + 1

    return dp[len_s1][len_s2]

def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if levenshtein_distance(word, w) <= max(len(word), len(w)) // 2]
    return suggestions

def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]/{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:
                misspelled_words[word] = suggestions
    return misspelled_words

df_filepath = r"C:\Users\ACER\Downloads\industry.csv"
with open(df_filepath, "r") as file:
    df_tokens = []
    for line in file:
        elements = line.strip().split(',')
        for element in elements:
            tokens = element.lower().strip().split(',')
            df_tokens.extend(tokens)

df_text = " ".join(df_tokens)

dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

misspelled_words = identify_misspelled_words(df_text, dictionary_content)

if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")
# Out:
# Misspelled words and suggestions:
# telecommunicationsht: ['telecommunications']

# %%
def matrix(rows,colums,initial=0):
    return initial[]*for i in range(len_s1 + 1)
def editdistance(df,sp):
    df=len(df)
    sp=len(sp)
  dp=def matrix(df+1,sp+1)
 for i in range(df+1)
   df[i][0]=i
 for j in range(sp+1)
   sp[0][j]=j
  for i in range(1,df+1)
   for j in range(1,sp+1)
       if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1]) + 1

    return dp[df][sp]

def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if editdistance(word, w) <= max(len(word), len(w)) // 2]
    return suggestions
def identify_misspelled_words(text, dictionary):
misspelled_words = {}
words = [word.strip(".,?!;:'\"()[]/{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:
                misspelled_words[word] = suggestions
    return misspelled_words
df_filepath = r"C:\Users\ACER\Downloads\industry.csv"
with open(df_filepath, "r") as file:
    df_tokens = []
    for line in file:
        elements = line.strip().split(',')
        for element in elements:
            tokens = element.lower().strip().split(',')
            df_tokens.extend(tokens)

df_text = " ".join(df_tokens)

dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

misspelled_words = identify_misspelled_words(df_text, dictionary_content)

if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")
# Out:
#   File <string>:6
#     dp=def matrix(df+1,sp+1)
#                             ^
# IndentationError: unindent does not match any outer indentation level

# %%
def initialize_matrix(rows, columns, initial=0):
    return [[initial] * columns for _ in range(rows)]

def edit_distance(s1, s2):
    len_s1 = len(s1)
    len_s2 = len(s2)
    
    dp = initialize_matrix(len_s1 + 1, len_s2 + 1)

    for i in range(len_s1 + 1):
        dp[i][0] = i

    for j in range(len_s2 + 1):
        dp[0][j] = j

    for i in range(1, len_s1 + 1):
        for j in range(1, len_s2 + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = min(dp[i - 1][j], dp[i][j - 1], dp[i - 1][j - 1]) + 1

    return dp[len_s1][len_s2]

def suggest_corrections(word, dictionary):
    suggestions = [w for w in dictionary if edit_distance(word, w) <= max(len(word), len(w)) // 2]
    return suggestions

def identify_misspelled_words(text, dictionary):
    misspelled_words = {}
    words = [word.strip(".,?!;:'\"()[]/{}") for word in text.split()]
    for word in words:
        if word.lower() not in dictionary:
            suggestions = suggest_corrections(word, dictionary)
            if suggestions:
                misspelled_words[word] = suggestions
    return misspelled_words

df_filepath = r"C:\Users\ACER\Downloads\industry.csv"
with open(df_filepath, "r") as file:
    df_tokens = []
    for line in file:
        elements = line.strip().split(',')
        for element in elements:
            tokens = element.lower().strip().split(',')
            df_tokens.extend(tokens)

df_text = " ".join(df_tokens)

dictionary_file_path = r"C:\Users\ACER\Downloads\industry.1.txt"
with open(dictionary_file_path, 'r') as file:
    dictionary_content = file.read().lower().split()

misspelled_words = identify_misspelled_words(df_text, dictionary_content)

if misspelled_words:
    print("Misspelled words and suggestions:")
    for word, suggestion_list in misspelled_words.items():
        print(f"{word}: {suggestion_list}")
else:
    print("No misspelled words found.")
# Out:
# Misspelled words and suggestions:
# relationsss: ['relations']
# automotivess: ['automotive']
# education/trainingss: ['education/training']
# insurancess: ['insurance']
# non-profyyit/volunteer: ['non-profit/volunteer']
# servicesss: ['service', 'services', 'service']
# telecommunicationsht: ['telecommunications']
